# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\abdul\OneDrive\Desktop\chinook_db\sql_music.csv')

# %%
df1=pd.read_csv(r'C:\Users\abdul\OneDrive\Desktop\chinook_db\top_albums_new_y.csv')

# %%
df2=pd.read_csv(r'C:\Users\abdul\OneDrive\Desktop\chinook_db\spent_rock.csv')

# %%
df3=pd.read_csv(r'C:\Users\abdul\OneDrive\Desktop\chinook_db\best_countrys.csv')

# %%
df.head(20)
# Out:
#    ArtistId            artist  songs
# 0        90       Iron Maiden    213
# 1       150                U2    135
# 2        22      Led Zeppelin    114
# 3        58       Deep Purple     92
# 4       118         Pearl Jam     67
# 5       100     Lenny Kravitz     57
# 6       152         Van Halen     52
# 7        51             Queen     45
# 8        84      Foo Fighters     44
# 9        88  'Guns N'' Roses'     42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ArtistId  10 non-null     int64
#  1   artist    10 non-null     object
#  2   songs     10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df.drop('ArtistId',axis=1,inplace=True)

# %%
df.head()
# Out:
#          artist  songs
# 0   Iron Maiden    213
# 1            U2    135
# 2  Led Zeppelin    114
# 3   Deep Purple     92
# 4     Pearl Jam     67

# %%
df.plot.bar(x='artist',y='songs')
plt.xlabel('top 10 hardworking artists')
plt.ylabel('number of songs wrote by the artist')
plt.title('who wrote more songs?')
# Out:
# Text(0.5, 1.0, 'who wrote more songs?')

# %%
df1.head()
# Out:
#                                       Title     season  AlbumId  \
# 0  Battlestar Galactica (Classic)  season1'   Season 1      253
# 1                       The Office season3'   Season 3      251
# 2                           Minha Historia'        one       23
# 3                             Lost season2'    season2      231
# 4                                Unplugged'        one       73
#
#    sales of each album
# 0                33.83
# 1                27.86
# 2                26.73
# 3                25.87
# 4                24.75

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                10 non-null     object
#  1   season               10 non-null     object
#  2   AlbumId              10 non-null     int64
#  3   sales of each album  10 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 448.0+ bytes

# %%
df1.plot.bar(x='Title',y='sales of each album')
plt.xlabel('titles of the albums')
plt.ylabel('sales of each album')
plt.title('top 10 albums')
# Out:
# Text(0.5, 1.0, 'top 10 albums')

# %%
df2.head(20)
# Out:
#     CustomerId  FirstName      LastName                        Email Genre  \
# 0           10    Eduardo       Martins     eduardo@woodstock.com.br  Rock
# 1           29     Robert         Brown             robbrown@shaw.ca  Rock
# 2           55       Mark        Taylor         mark.taylor@yahoo.au  Rock
# 3           50    Enrique         Muñoz       enrique_munoz@yahoo.es  Rock
# 4           49  Stanisław        Wójcik       stanisław.wójcik@wp.pl  Rock
# 5           38     Niklas      Schröder          nschroder@surfeu.de  Rock
# 6            9       Kara       Nielsen        kara.nielsen@jubii.dk  Rock
# 7            8       Daan       Peeters        daan_peeters@apple.be  Rock
# 8           33      Ellie      Sullivan       ellie.sullivan@shaw.ca  Rock
# 9           30     Edward       Francis          edfrancis@yachoo.ca  Rock
# 10          18   Michelle        Brooks            michelleb@aol.com  Rock
# ...

# %%
df_top=df2[0:10]

# %%
df_top
# Out:
#    CustomerId  FirstName  LastName                     Email Genre  \
# 0          10    Eduardo   Martins  eduardo@woodstock.com.br  Rock
# 1          29     Robert     Brown          robbrown@shaw.ca  Rock
# 2          55       Mark    Taylor      mark.taylor@yahoo.au  Rock
# 3          50    Enrique     Muñoz    enrique_munoz@yahoo.es  Rock
# 4          49  Stanisław    Wójcik    stanisław.wójcik@wp.pl  Rock
# 5          38     Niklas  Schröder       nschroder@surfeu.de  Rock
# 6           9       Kara   Nielsen     kara.nielsen@jubii.dk  Rock
# 7           8       Daan   Peeters     daan_peeters@apple.be  Rock
# 8          33      Ellie  Sullivan    ellie.sullivan@shaw.ca  Rock
# 9          30     Edward   Francis       edfrancis@yachoo.ca  Rock
#
#    spent on Rock
# 0          28.71
# 1          24.75
# 2          21.78
# 3          21.78
# 4          21.78
# 5          20.79
# 6          20.79
# 7          20.79
# 8          18.81
# 9          18.81

# %%
df_top.plot.bar(x='LastName',y='spent on Rock')
plt.xlabel('customers lastnames')
plt.ylabel('customers spendings on rock music')
plt.title('top 10 Rock lovers')
# Out:
# Text(0.5, 1.0, 'top 10 Rock lovers')

# %%
df3.head(20)
# Out:
#           Country  money paied by customers in each country   \
# 0             USA                                    4667.06
# 1          Canada                                    2689.96
# 2          France                                    1722.10
# 3          Brazil                                    1677.10
# 4         Germany                                    1392.48
# 5  United Kingdom                                    1003.86
# 6  Czech Republic                                     879.24
# 7        Portugal                                     687.24
# 8           India                                     667.28
# 9         Ireland                                     446.62
#
#    total quatity ordered
# 0                    494
# 1                    304
# 2                    190
# 3                    190
# 4                    152
# 5                    114
# 6                     76
# 7                     76
# 8                     74
# 9                     38

# %%
df3.plot.bar(x='Country',y='total quatity ordered')
plt.xlabel('countries')
plt.ylabel('quantity ordered by our customers in each country')
plt.title('where do most of our valuable customers live?')
# Out:
# Text(0.5, 1.0, 'where do most of our valuable customers live?')
